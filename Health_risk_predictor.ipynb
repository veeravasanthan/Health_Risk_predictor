# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Projects\Health_Risk_predictor\synthetic_health_data.csv")

# %%
print(df)
# Out:
#       age     diet  exercise_days  sleep_hours  stress   bmi smoking alcohol  \
# 0      56     Poor              3            4    High  19.9      No    High
# 1      69  Average              2            5    High  33.9      No     Low
# 2      46  Average              7           12  Medium  31.0     Yes     Low
# 3      32     Good              1           11    High  38.1      No    High
# 4      60     Good              6           11     Low  34.6      No     Low
# ...   ...      ...            ...          ...     ...   ...     ...     ...
# 3995   35     Poor              7            7     Low  16.6      No     Low
# 3996   22  Average              6            8  Medium  38.8      No     Low
# 3997   20     Poor              5            8     Low  30.3      No  Medium
# 3998   40     Poor              2            3     Low  35.0      No     Low
# 3999   43  Average              7           11  Medium  25.2     Yes  Medium
#
#      family_history risk_level
# ...

# %%
df
# Out:
#       age     diet  exercise_days  sleep_hours  stress   bmi smoking alcohol  \
# 0      56     Poor              3            4    High  19.9      No    High
# 1      69  Average              2            5    High  33.9      No     Low
# 2      46  Average              7           12  Medium  31.0     Yes     Low
# 3      32     Good              1           11    High  38.1      No    High
# 4      60     Good              6           11     Low  34.6      No     Low
# ...   ...      ...            ...          ...     ...   ...     ...     ...
# 3995   35     Poor              7            7     Low  16.6      No     Low
# 3996   22  Average              6            8  Medium  38.8      No     Low
# 3997   20     Poor              5            8     Low  30.3      No  Medium
# 3998   40     Poor              2            3     Low  35.0      No     Low
# 3999   43  Average              7           11  Medium  25.2     Yes  Medium
#
#      family_history risk_level
# ...

# %%
df.shape
# Out:
# (4000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4000 non-null   int64
#  1   diet            4000 non-null   object
#  2   exercise_days   4000 non-null   int64
#  3   sleep_hours     4000 non-null   int64
#  4   stress          4000 non-null   object
#  5   bmi             4000 non-null   float64
#  6   smoking         4000 non-null   object
#  7   alcohol         4000 non-null   object
#  8   family_history  4000 non-null   object
#  9   risk_level      4000 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 312.6+ KB

# %%
df.isna().sum
# Out:
# <bound method DataFrame.sum of         age   diet  exercise_days  sleep_hours  stress    bmi  smoking  \
# 0     False  False          False        False   False  False    False
# 1     False  False          False        False   False  False    False
# 2     False  False          False        False   False  False    False
# 3     False  False          False        False   False  False    False
# 4     False  False          False        False   False  False    False
# ...     ...    ...            ...          ...     ...    ...      ...
# 3995  False  False          False        False   False  False    False
# 3996  False  False          False        False   False  False    False
# 3997  False  False          False        False   False  False    False
# 3998  False  False          False        False   False  False    False
# 3999  False  False          False        False   False  False    False
#
#       alcohol  family_history  risk_level
# 0       False           False       False
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    age     diet  exercise_days  sleep_hours  stress   bmi smoking alcohol  \
# 0   56     Poor              3            4    High  19.9      No    High
# 1   69  Average              2            5    High  33.9      No     Low
# 2   46  Average              7           12  Medium  31.0     Yes     Low
# 3   32     Good              1           11    High  38.1      No    High
# 4   60     Good              6           11     Low  34.6      No     Low
#
#   family_history risk_level
# 0            Yes       High
# 1            Yes       High
# 2            Yes     Medium
# 3             No     Medium
# 4            Yes     Medium

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4000 non-null   int64
#  1   diet            4000 non-null   object
#  2   exercise_days   4000 non-null   int64
#  3   sleep_hours     4000 non-null   int64
#  4   stress          4000 non-null   object
#  5   bmi             4000 non-null   float64
#  6   smoking         4000 non-null   object
#  7   alcohol         4000 non-null   object
#  8   family_history  4000 non-null   object
#  9   risk_level      4000 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 312.6+ KB

# %%
df['age'].max()
# Out:
# np.int64(80)

# %%
df['diet'].value_counts()
# Out:
# diet
# Average    1987
# Poor       1216
# Good        797
# Name: count, dtype: int64

# %%
df['exercise_days'].max()
# Out:
# np.int64(7)

# %%
df['exercise_days'].min()
# Out:
# np.int64(0)

# %%
df['sleep_hours'].max()
# Out:
# np.int64(12)

# %%
df['sleep_hours'].min()
# Out:
# np.int64(3)

# %%
df.head()
# Out:
#    age     diet  exercise_days  sleep_hours  stress   bmi smoking alcohol  \
# 0   56     Poor              3            4    High  19.9      No    High
# 1   69  Average              2            5    High  33.9      No     Low
# 2   46  Average              7           12  Medium  31.0     Yes     Low
# 3   32     Good              1           11    High  38.1      No    High
# 4   60     Good              6           11     Low  34.6      No     Low
#
#   family_history risk_level
# 0            Yes       High
# 1            Yes       High
# 2            Yes     Medium
# 3             No     Medium
# 4            Yes     Medium

# %%
categorical_col=['diet','stress','smoking','alcohol','family_history','risk_level']

# %%
# !pip install scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoders={}

# %%
for i in categorical_col:
    le=LabelEncoder()
    df[i]=le.fit_transform(df[i])
    encoders[i]=le

# %%
df.head()
# Out:
#    age  diet  exercise_days  sleep_hours  stress   bmi  smoking  alcohol  \
# 0   56     2              3            4       0  19.9        0        0
# 1   69     0              2            5       0  33.9        0        1
# 2   46     0              7           12       2  31.0        1        1
# 3   32     1              1           11       0  38.1        0        0
# 4   60     1              6           11       1  34.6        0        1
#
#    family_history  risk_level
# 0               1           0
# 1               1           0
# 2               1           2
# 3               0           2
# 4               1           2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4000 non-null   int64
#  1   diet            4000 non-null   int64
#  2   exercise_days   4000 non-null   int64
#  3   sleep_hours     4000 non-null   int64
#  4   stress          4000 non-null   int64
#  5   bmi             4000 non-null   float64
#  6   smoking         4000 non-null   int64
#  7   alcohol         4000 non-null   int64
#  8   family_history  4000 non-null   int64
#  9   risk_level      4000 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 312.6 KB

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns='risk_level')
y=df['risk_level']

# %%
print(x.columns)
# Out:
# Index(['age', 'diet', 'exercise_days', 'sleep_hours', 'stress', 'bmi',
#        'smoking', 'alcohol', 'family_history'],
#       dtype='object')

# %%
print(y.name)
# Out:
# risk_level

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
#model=LogisticRegression()
model=RandomForestClassifier(n_estimators=100,random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred=model.predict(x_test)

# %%
acc=accuracy_score(y_pred,y_test)

# %%
print("accuracy score of your model is:",acc)
# Out:
# accuracy score of your model is: 0.96375

# %%
#demo

# %%
df.head()
# Out:
#    age  diet  exercise_days  sleep_hours  stress   bmi  smoking  alcohol  \
# 0   56     2              3            4       0  19.9        0        0
# 1   69     0              2            5       0  33.9        0        1
# 2   46     0              7           12       2  31.0        1        1
# 3   32     1              1           11       0  38.1        0        0
# 4   60     1              6           11       1  34.6        0        1
#
#    family_history  risk_level
# 0               1           0
# 1               1           0
# 2               1           2
# 3               0           2
# 4               1           2

# %%
model.predict([[56,2,3,4,0,19.9,0,0,1]])
# Out:
# c:\Users\veera\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import pickle

# %%
pickle.dump(model,open('Health_risk_predictor.pkl','wb'))

# %%
with open("label_encoders.pkl","wb") as f:
    pickle.dump(encoders,f)
